# %%
from transformers import AutoTokenizer, AutoModel
from datasets import load_from_disk, DatasetDict, concatenate_datasets, Dataset
import transformers
import torch

# %%
print(torch.__version__)          
print(torch.version.cuda)        
print(torch.cuda.is_available()) 
print(transformers.__version__)
# Out:
# 2.9.1+cu130
# 13.0
# True

# %%
dataset = load_from_disk(r"Data\multiauthor_dataset")

# %% [markdown]
# Flatten dataset for tokenization

# %%
def flatten_dataset(dataset):
    flat_examples = []
    for item in dataset:
        for sent, change in zip(item["text"], item["changes"]):
            flat_examples.append({
                "problem_id": item["id"],
                "sentence": sent,
                "label": change,
                "difficulty": item["difficulty"],
                "authors": item["authors"]
            })
    return Dataset.from_list(flat_examples)

# %% [markdown]
# Tokenize dataset to be ready for model training

# %%
tokenizer = AutoTokenizer.from_pretrained("jhu-clsp/mmBERT-base", trust_remote_code=True)

def tokenize_fn(example):
    return tokenizer(example["sentence"], truncation=True, padding="max_length")

# step by step approach
#flat_dataset_easy = flatten_dataset(dataset["train_easy"]) 
#tokenized_dataset_easy = flat_dataset_easy.map(tokenize_fn)
#flat_dataset_medium = flatten_dataset(dataset["train_medium"])
#tokenized_dataset_medium = flat_dataset_medium.map(tokenize_fn)
#flat_dataset_hard = flatten_dataset(dataset["train_hard"]) 
#tokenized_dataset_hard = flat_dataset_hard.map(tokenize_fn)


tokenized_splits = {}

for split_name in ["train_easy", "train_medium", "train_hard"]:
    flat = flatten_dataset(dataset[split_name])
    tokenized = flat.map(tokenize_fn, batched=True)  # batched=True speeds things up
    tokenized_splits[split_name] = tokenized

tokenized_dataset = DatasetDict(tokenized_splits)
# Out:
# ...
# Map:   0%|          | 0/51061 [00:00<?, ? examples/s]

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train_easy: Dataset({
#         features: ['problem_id', 'sentence', 'label', 'difficulty', 'authors', 'input_ids', 'attention_mask'],
#         num_rows: 48402
#     })
#     train_medium: Dataset({
#         features: ['problem_id', 'sentence', 'label', 'difficulty', 'authors', 'input_ids', 'attention_mask'],
#         num_rows: 58817
#     })
#     train_hard: Dataset({
#         features: ['problem_id', 'sentence', 'label', 'difficulty', 'authors', 'input_ids', 'attention_mask'],
#         num_rows: 51061
#     })
# })

# %% [markdown]
# Save dataset locally

# %%
tokenized_dataset.save_to_disk("data/mmbert_tokenized_dataset")
# Out:
# ...
# Saving the dataset (0/5 shards):   0%|          | 0/51061 [00:00<?, ? examples/s]
